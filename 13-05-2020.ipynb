# %%
print("WELCOME")
# Out:
# WELCOME

# %%
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %%
import os
dir(os)
# Out:
# ['CLD_CONTINUED',
#  'CLD_DUMPED',
#  'CLD_EXITED',
#  'CLD_TRAPPED',
#  'DirEntry',
#  'EX_CANTCREAT',
#  'EX_CONFIG',
#  'EX_DATAERR',
#  'EX_IOERR',
#  'EX_NOHOST',
#  'EX_NOINPUT',
#  'EX_NOPERM',
#  'EX_NOUSER',
#  'EX_OK',
#  'EX_OSERR',
#  'EX_OSFILE',
#  'EX_PROTOCOL',
#  'EX_SOFTWARE',
#  'EX_TEMPFAIL',
#  'EX_UNAVAILABLE',
#  'EX_USAGE',
#  'F_LOCK',
#  'F_OK',
#  'F_TEST',
#  'F_TLOCK',
#  'F_ULOCK',
#  'GRND_NONBLOCK',
#  'GRND_RANDOM',
#  'MutableMapping',
#  'NGROUPS_MAX',
#  'O_ACCMODE',
#  'O_APPEND',
#  'O_ASYNC',
#  'O_CLOEXEC',
#  'O_CREAT',
#  'O_DIRECT',
#  'O_DIRECTORY',
#  'O_DSYNC',
#  'O_EXCL',
#  'O_LARGEFILE',
#  'O_NDELAY',
#  'O_NOATIME',
#  'O_NOCTTY',
#  'O_NOFOLLOW',
#  'O_NONBLOCK',
#  'O_PATH',
#  'O_RDONLY',
#  'O_RDWR',
#  'O_RSYNC',
#  'O_SYNC',
#  'O_TMPFILE',
#  'O_TRUNC',
#  'O_WRONLY',
#  'POSIX_FADV_DONTNEED',
#  'POSIX_FADV_NOREUSE',
#  'POSIX_FADV_NORMAL',
#  'POSIX_FADV_RANDOM',
#  'POSIX_FADV_SEQUENTIAL',
#  'POSIX_FADV_WILLNEED',
# ...

# %%
methods = [ i for i in dir('') if i[0].islower()]
fmt='{:15s}'*4 
for fn in zip(*[iter(methods)] * 4):
    print(fmt.format(*fn))
# Out:
# capitalize     casefold       center         count
# encode         endswith       expandtabs     find
# format         format_map     index          isalnum
# isalpha        isdecimal      isdigit        isidentifier
# islower        isnumeric      isprintable    isspace
# istitle        isupper        join           ljust
# lower          lstrip         maketrans      partition
# replace        rfind          rindex         rjust
# rpartition     rsplit         rstrip         split
# splitlines     startswith     strip          swapcase
# title          translate      upper          zfill

# %%
from pathlib import Path

P = Path("/etc/passwd").read_text().splitlines()
print(P)
# Out:
# ['root:x:0:0:root:/root:/bin/bash', 'daemon:x:1:1:daemon:/usr/sbin:/usr/sbin/nologin', 'bin:x:2:2:bin:/bin:/usr/sbin/nologin', 'sys:x:3:3:sys:/dev:/usr/sbin/nologin', 'sync:x:4:65534:sync:/bin:/bin/sync', 'games:x:5:60:games:/usr/games:/usr/sbin/nologin', 'man:x:6:12:man:/var/cache/man:/usr/sbin/nologin', 'lp:x:7:7:lp:/var/spool/lpd:/usr/sbin/nologin', 'mail:x:8:8:mail:/var/mail:/usr/sbin/nologin', 'news:x:9:9:news:/var/spool/news:/usr/sbin/nologin', 'uucp:x:10:10:uucp:/var/spool/uucp:/usr/sbin/nologin', 'proxy:x:13:13:proxy:/bin:/usr/sbin/nologin', 'www-data:x:33:33:www-data:/var/www:/usr/sbin/nologin', 'backup:x:34:34:backup:/var/backups:/usr/sbin/nologin', 'list:x:38:38:Mailing List Manager:/var/list:/usr/sbin/nologin', 'irc:x:39:39:ircd:/var/run/ircd:/usr/sbin/nologin', 'gnats:x:41:41:Gnats Bug-Reporting System (admin):/var/lib/gnats:/usr/sbin/nologin', 'nobody:x:65534:65534:nobody:/nonexistent:/usr/sbin/nologin', 'systemd-network:x:100:102:systemd Network Management,,,:/run/syst
# ...

# %%
name = 'Raja Selvaraj'
name[::-1]
# Out:
# 'jaravleS ajaR'

# %%
lang = 'Python'
print('='*21)
print(*range(len(lang)),sep=' | ')
print('-'*21)
print(*lang, sep=' | ')
print('-'*21)
print(*range(-len(lang),0,1),sep='| ')
print('='*21)
# Out:
# ...
# 0 | 1 | 2 | 3 | 4 | 5
# ---------------------
# P | y | t | h | o | n
# ---------------------
# -6| -5| -4| -3| -2| -1
# ...

# %%
lang = 'Python'
print('='*21)
print(*lang, sep='|')
print('-'*21)
print(*range(-len(lang),0,1),sep='  |')
print('='*21)
# Out:
# ...
# P|y|t|h|o|n
# ---------------------
# -6|-5|-4|-3|-2|-1
# ...

# %%
import pwd
pass_dict={}
for i in pwd.getpwall():
      pass_dict.setdefault(i[0],[]).extend(i[2:])
pass_dict
# Out:
# {'_apt': [104, 65534, '', '/nonexistent', '/usr/sbin/nologin'],
#  'ansible': [1000, 1000, ',,,', '/home/ansible', '/bin/bash'],
#  'backup': [34, 34, 'backup', '/var/backups', '/usr/sbin/nologin'],
#  'bin': [2, 2, 'bin', '/bin', '/usr/sbin/nologin'],
#  'daemon': [1, 1, 'daemon', '/usr/sbin', '/usr/sbin/nologin'],
#  'dnsmasq': [107, 65534, 'dnsmasq,,,', '/var/lib/misc', '/usr/sbin/nologin'],
#  'games': [5, 60, 'games', '/usr/games', '/usr/sbin/nologin'],
#  'gnats': [41,
#   41,
#   'Gnats Bug-Reporting System (admin)',
#   '/var/lib/gnats',
#   '/usr/sbin/nologin'],
#  'irc': [39, 39, 'ircd', '/var/run/ircd', '/usr/sbin/nologin'],
#  'landscape': [108, 112, '', '/var/lib/landscape', '/usr/sbin/nologin'],
#  'list': [38, 38, 'Mailing List Manager', '/var/list', '/usr/sbin/nologin'],
#  'lp': [7, 7, 'lp', '/var/spool/lpd', '/usr/sbin/nologin'],
#  'lxd': [105, 65534, '', '/var/lib/lxd/', '/bin/false'],
#  'mail': [8, 8, 'mail', '/var/mail', '/usr/sbin/nologin'],
# ...

# %%
##** Find the biggest number in list without builtin function**

# %%
lst = [ 3,11,1,2,4,3,5,7,6,3]

big = 0 

for i in lst:
    if i>=big:
        big=i
        
print("Biggest Number {}".format(big))
# Out:
# Biggest Number 11

# %%
myarray = [ [11,22,33,44], [55,66,77,88]]
print(myarray[::-1])
# Out:
# [[55, 66, 77, 88], [11, 22, 33, 44]]

# %%
A = int(input("Enter the price for Old Scooter:"))

B = int(input("Enter the price for Repair:"))

C = float(input("Enter the selling price:"))

TotalCost = A + B 

Gain = (C - TotalCost) 

GainP = Gain/TotalCost * 100

print("{:.2f}".format(GainP))
# Out:
# Enter the price for Old Scooter:4700
# Enter the price for Repair:800
# Enter the selling price:5800
# 5.45

# %%
m= int(input())

def non_prime(a):
    if a>1:
        for i in range(2, int(a/2)): 
            if (a % i) == 0:
                print("number is not prime number")
                break
            else:
                print("number is prime number")
    else:
        print("number is not prime number")
        

check_prime=non_prime(m)
# Out:
# 23
# number is prime number
# number is prime number
# number is prime number
# number is prime number
# number is prime number
# number is prime number
# number is prime number
# number is prime number
# number is prime number

# %%
# %%bash
#
# awk -F ":" '{ print $6}' /etc/passwd
# Out:
# /root
# /usr/sbin
# /bin
# /dev
# /bin
# /usr/games
# /var/cache/man
# /var/spool/lpd
# /var/mail
# /var/spool/news
# /var/spool/uucp
# /bin
# /var/www
# /var/backups
# /var/list
# /var/run/ircd
# /var/lib/gnats
# /nonexistent
# /run/systemd/netif
# /run/systemd/resolve
# /home/syslog
# /nonexistent
# /nonexistent
# /var/lib/lxd/
# /run/uuidd
# /var/lib/misc
# /var/lib/landscape
# /run/sshd
# /var/cache/pollinate
# /home/ansible

# %% [markdown]
# ##**Methods**
